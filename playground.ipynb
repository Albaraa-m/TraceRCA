# %%
import pickle
import pprint
import pandas as pd

# %%
# file = 'A/container/basic_delay_0415.pkl'
# file = 'A/container/route_delay_0415.pkl'
# file = 'A/container/train_delay_0415.pkl'
# file = 'output/trainticket_root_cause_localization/admin-order_abort_1011.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/auth_cpu_1016.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/config_delay_1010.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_invo_encoded/admin-order_abort_1011.invo.pkl'
from pathlib import Path


dir = 'output/trainticket_anomaly_detection.test'
files = list(Path(dir).glob('*'))
for file in files:
    with open(file, 'rb') as f:
        data = pickle.load(f)
    print(data)
# Out:
# ['basic', 'cpu']                              trace_id  RF-Trace-predict  MLP-Trace-predict  \
# 0    09d9775e41500c1975ddf5f3830a4130             False              False
# 1    49147598d4c0100a8424c9a9696309c3             False              False
# 2    9869da631478ff974088ea6d9f825c80             False              False
# 3    df77e537c4b23137b936b3a67bb59031             False              False
# 4    f84f45d4c2e3298f46cb606476940782             False              False
# ..                                ...               ...                ...
# 978                                               False              False
# 979  a5ca4554d69c390d4065f730dc5ccb9e             False              False
# 980  34e1a6758252ad404243815a495d67d8             False              False
# 981                                               False              False
# 982  511fde39996b73067eaef2d9e0752f01             False              False
#
#      trace_label
# 0           True
# ...

# %%
# file = 'A/container/basic_delay_0415.pkl'
# file = 'A/container/route_delay_0415.pkl'
# file = 'A/container/train_delay_0415.pkl'
# file = 'output/trainticket_root_cause_localization/admin-order_abort_1011.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/auth_cpu_1016.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/config_delay_1010.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_invo_encoded/admin-order_abort_1011.invo.pkl'
from pathlib import Path


dir = 'output/trainticket_anomaly_detection.test'
file = 'output/trainticket_anomaly_detection.test/basic_delay_0414.trace.result.pkl.0.0'
file = 'output/trainticket_anomaly_detection.test/basic_delay_0414.useful_features.3'
file = 'output/trainticket_invo_encoded/basic_delay_0414.invo.pkl'
file = 'output/trainticket_anomaly_detection.test/basic_delay_0414.trace.result.pkl.0.0'
file = 'output/trainticket_anomaly_detection.models.0.0'
# files = list(Path(dir).glob('*'))
with open(file, 'rb') as f:
    data = pickle.load(f)
pprint.pprint(data)
# Out:
# {'IF-admin-basic-info-config': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-basic-info-contacts': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-basic-info-price': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-basic-info-station': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-basic-info-train': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-order-order': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-order-order-other': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-route-route': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-travel-travel': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-travel-travel2': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-admin-user-user': IsolationForest(contamination=0.01, n_jobs=10),
#  'IF-auth-verification-code': IsolationForest(contamination=0.01, n_jobs=10),
# ...

# %%
# file = 'A/container/basic_delay_0415.pkl'
# file = 'A/container/route_delay_0415.pkl'
# file = 'A/container/train_delay_0415.pkl'
# file = 'output/trainticket_root_cause_localization/admin-order_abort_1011.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/auth_cpu_1016.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/config_delay_1010.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_invo_encoded/admin-order_abort_1011.invo.pkl'
from pathlib import Path


dir = 'output/trainticket_root_cause_localization'
files = list(Path(dir).glob('*'))
for file in files:
    with open(file, 'rb') as f:
        data = pickle.load(f)
    filename = str(file).split('/')[-1].split('_')[:2]
    print(filename, data)
# Out:
# ['basic', 'abort'] {'Ours-noise=0': ['basic', 'travel', 'travel-plan', 'ticketinfo', 'route-plan', 'auth', 'consign', 'verification-code']}
# ['basic', 'cpu'] {'Ours-noise=0': ['basic', 'travel', 'train', 'ticketinfo', 'travel2', 'preserve', 'travel-plan', 'price', 'config', 'security', 'route', 'station', 'seat', 'ui-dashboard', 'order-other', 'user', 'payment', 'auth', 'assurance', 'food', 'preserve-other', 'contacts', 'order', 'route-plan', 'verification-code', 'food-map', 'consign', 'inside-payment', 'admin-order', 'cancel', 'notification']}
# ['basic', 'delay'] {'Ours-noise=0': ['basic', 'travel', 'ticketinfo', 'config', 'station', 'seat', 'price', 'order', 'route', 'train', 'consign', 'auth', 'travel-plan', 'route-plan', 'verification-code']}
# ['basic', 'abort'] {'Ours-noise=0': ['travel', 'ticketinfo', 'travel-plan', 'basic', 'route-plan', 'consign', 'auth', 'verification-code']}
# ...

# %%
# file = 'A/container/basic_delay_0415.pkl'
# file = 'A/container/route_delay_0415.pkl'
# file = 'A/container/train_delay_0415.pkl'
# file = 'output/trainticket_root_cause_localization/admin-order_abort_1011.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/auth_cpu_1016.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_root_cause_localization/config_delay_1010.association_rule_mining.result.pkl.0.1.100'
# file = 'output/trainticket_invo_encoded/admin-order_abort_1011.invo.pkl'
from pathlib import Path


dir = 'output/trainticket_root_cause_localization'

files = list(Path(dir).glob('*'))
for file in files:
    with open(file, 'rb') as f:
        data = pickle.load(f)
    filename = str(file).split('/')[-1].split('_')[:2]
    print(filename, data)
# Out:
# ['order-other', 'delay'] {'Ours-noise=0': ['order-other', 'security', 'ui-dashboard', 'order', 'preserve', 'station', 'travel-plan', 'cancel', 'inside-payment', 'route', 'config', 'basic', 'travel2', 'verification-code', 'assurance', 'food', 'train', 'user', 'travel', 'consign', 'price', 'food-map', 'route-plan', 'auth', 'contacts', 'preserve-other', 'seat', 'ticketinfo']}
# ['security', 'delay'] {'Ours-noise=0': ['cancel', 'inside-payment', 'order', 'order-other', 'ui-dashboard', 'price', 'assurance', 'travel-plan', 'seat', 'config', 'basic', 'preserve', 'station', 'route-plan', 'ticketinfo', 'train', 'travel2', 'consign', 'food', 'food-map', 'preserve-other', 'user', 'contacts', 'travel', 'route', 'auth', 'verification-code', 'security']}
# ...

# %%
file = '/Users/albaraamirdad/coding/TraceRCA/A/container/basic_delay_0415.pkl'
file = 'A/container/route_delay_0415.pkl'
file = 'A/test/admin-order_abort_1011.pkl'
file = 'output/trainticket_root_cause_localization/user_delay_0430.association_rule_mining.result.pkl.0.1.100'
file = 'tracerca-exp/data/test/basic_delay_0414.pkl'
file = 'A/API/user_delay_0421.pkl'
file = 'output/trainticket_anomaly_detection.test/user_cpu_1016.trace.result.pkl.0.0'
file = 'output/trainticket_anomaly_detection.test/user_cpu_1016.invo.result.pkl.1.3'
with open(file, 'rb') as f:
    data = pickle.load(f)

pprint.pprint(data)
# Out:
#                               trace_id  RF-Trace-predict  MLP-Trace-predict  \
# 0     0ab5de36dcf9a6ffbed693d7bfbcbbad             False              False
# 1     24bbe88b7edcbef6702f08b5b4b98d74             False              False
# 2     0854e1ad92188ad9b6f93a306264d2c0             False              False
# 3     9082eccfe9ad111fdc138aa9ecc0fd9f             False              False
# 4     caecdd6edcb6cfe4ed4ac6b8a1fd0c7a             False              False
# ...                                ...               ...                ...
# 2484                                               False              False
# 2485                                               False              False
# 2486                                               False              False
# 2487                                               False              False
# 2488  845f3fcf6a89b84b64651290c3fb3cca             False              False
#
#       trace_label
# 0           False
# ...
